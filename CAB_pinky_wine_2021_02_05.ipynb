# %%
# load dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

red_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep= ';')
white_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep= ';')

# %%
red_wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
red_wine.astype('int64').dtypes
# Out:
# fixed acidity           int64
# volatile acidity        int64
# citric acid             int64
# residual sugar          int64
# chlorides               int64
# free sulfur dioxide     int64
# total sulfur dioxide    int64
# density                 int64
# pH                      int64
# sulphates               int64
# alcohol                 int64
# quality                 int64
# dtype: object

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
white_wine.astype('int64').dtypes
# Out:
# fixed acidity           int64
# volatile acidity        int64
# citric acid             int64
# residual sugar          int64
# chlorides               int64
# free sulfur dioxide     int64
# total sulfur dioxide    int64
# density                 int64
# pH                      int64
# sulphates               int64
# alcohol                 int64
# quality                 int64
# dtype: object

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# bucket wine quality scores into qualitative quality labels
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])
red_wine['quality_label'].dtype
# Out:
# CategoricalDtype(categories=['low', 'medium', 'high'], ordered=False)

# %%
# create a new variable 'wine_type'
white_wine['wine_type'] = 'white'

# bucket wine quality scores into qualitative quality labels

white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# combine two dataframe (red_wine) & (white_wine)
wines = pd.concat([red_wine, white_wine])

# re-shuffle records just to randomize data points
wines = wines.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
wines
# Out:
#       alcohol  chlorides  citric acid  density  fixed acidity  \
# 0        12.2      0.045         0.74  0.99420            7.0
# 1         9.9      0.077         0.21  0.99560            7.7
# 2        12.0      0.020         0.34  0.99212            6.8
# 3         9.5      0.040         0.47  0.99592            6.3
# 4         8.9      0.054         0.20  0.99888            7.4
# ...       ...        ...          ...      ...            ...
# 6492      9.2      0.050         0.58  0.99990            7.6
# 6493     10.7      0.043         0.27  0.99202            5.6
# 6494      9.5      0.117         0.20  0.99459            6.4
# 6495      9.5      0.051         0.50  0.99536            6.5
# 6496      9.5      0.077         0.06  0.99746            7.2
#
#       free sulfur dioxide    pH  quality quality_label  residual sugar  \
# 0                    24.0  3.26        8          high           12.80
# 1                    32.0  3.27        5           low            2.20
# ...

# %%
wines['wine_type'] = wines['wine_type'].replace(np.nan, 'red')

# %%
wines
# Out:
#       alcohol  chlorides  citric acid  density  fixed acidity  \
# 0        12.2      0.045         0.74  0.99420            7.0
# 1         9.9      0.077         0.21  0.99560            7.7
# 2        12.0      0.020         0.34  0.99212            6.8
# 3         9.5      0.040         0.47  0.99592            6.3
# 4         8.9      0.054         0.20  0.99888            7.4
# ...       ...        ...          ...      ...            ...
# 6492      9.2      0.050         0.58  0.99990            7.6
# 6493     10.7      0.043         0.27  0.99202            5.6
# 6494      9.5      0.117         0.20  0.99459            6.4
# 6495      9.5      0.051         0.50  0.99536            6.5
# 6496      9.5      0.077         0.06  0.99746            7.2
#
#       free sulfur dioxide    pH  quality quality_label  residual sugar  \
# 0                    24.0  3.26        8          high           12.80
# 1                    32.0  3.27        5           low            2.20
# ...

# %%
# wines['wine_type'] = wines['wine_type'].replace(wines['wine_type'] = np.nan, 'red')
# wines.loc[wines.wine_type = np.nan].fillna('red')
# wines.fillna(method='WORD', inplace=True)
# wines.fillna(0, inplace=True)
# wines[wines['wine_type'] != 'white']

# wines['ID'] = wines.index
# wines['wine_type'] = wines[wines.isna().any(axis=1)].replace(np.nan,'red')
# wines['wine_type'] = wines['ID'].map(wines_red.set_index('ID')['wine_type'])

# %%
# Which factor or combination of factors affect the quality of red & white wines
# do the diffrent types of wines have different factors affecting quality?
# Is there any other intresting trends that exist in other columns besides quality?

# %%
# Check how you can print first, last 10 records.
wines.head(10)
# Out:
#    alcohol  chlorides  citric acid  density  fixed acidity  \
# 0     12.2      0.045         0.74  0.99420            7.0
# 1      9.9      0.077         0.21  0.99560            7.7
# 2     12.0      0.020         0.34  0.99212            6.8
# 3      9.5      0.040         0.47  0.99592            6.3
# 4      8.9      0.054         0.20  0.99888            7.4
# 5     12.1      0.064         0.14  0.99323            7.2
# 6     10.2      0.051         0.31  0.99900            7.5
# 7      9.9      0.044         0.27  0.99454            6.8
# 8      9.2      0.078         0.49  0.99780            9.0
# 9     11.3      0.034         0.30  0.99121            7.1
#
#    free sulfur dioxide    pH  quality quality_label  residual sugar  \
# 0                 24.0  3.26        8          high            12.8
# 1                 32.0  3.27        5           low             2.2
# 2                 38.0  3.18        7        medium             7.4
# ...

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
# alcohol                 6497 non-null float64
# chlorides               6497 non-null float64
# citric acid             6497 non-null float64
# density                 6497 non-null float64
# fixed acidity           6497 non-null float64
# free sulfur dioxide     6497 non-null float64
# pH                      6497 non-null float64
# quality                 6497 non-null int64
# quality_label           6497 non-null category
# residual sugar          6497 non-null float64
# sulphates               6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# volatile acidity        6497 non-null float64
# wine_type               6497 non-null object
# dtypes: category(1), float64(11), int64(1), object(1)
# memory usage: 666.4+ KB

# %%
wines.shape
# Out:
# (6497, 14)

# %%
# Observe if there is missing values
nan_wines = wines[wines.isna().any(axis=1)]
nan_wines

# shows there is no NaN values
# Out:
# Empty DataFrame
# Columns: [alcohol, chlorides, citric acid, density, fixed acidity, free sulfur dioxide, pH, quality, quality_label, residual sugar, sulphates, total sulfur dioxide, volatile acidity, wine_type]
# Index: []

# %%
# Can you create a table like below to compare the Descriptive Statistics between Red wine and White wine.

pd.concat([red_wine, white_wine], keys=['red_wine Statistics', 'white_wine Statistics'],axis=1)
# Out:
#      red_wine Statistics                                              \
#            fixed acidity volatile acidity citric acid residual sugar
# 0                    7.4             0.70        0.00            1.9
# 1                    7.8             0.88        0.00            2.6
# 2                    7.8             0.76        0.04            2.3
# 3                   11.2             0.28        0.56            1.9
# 4                    7.4             0.70        0.00            1.9
# ...                  ...              ...         ...            ...
# 4893                 NaN              NaN         NaN            NaN
# 4894                 NaN              NaN         NaN            NaN
# 4895                 NaN              NaN         NaN            NaN
# 4896                 NaN              NaN         NaN            NaN
# 4897                 NaN              NaN         NaN            NaN
#
# ...

# %%
fig1, ax = plt.subplots(1,2)
ax[0].boxplot(wines.loc[wines['wine_type'] == 'red','alcohol']);
ax[0].set_title('Basic alcohol Plot Red wine')
ax[1].boxplot(wines.loc[wines['wine_type'] == 'white','alcohol']);
ax[1].set_title('Basic alcohol  Plot white Wine');

# %%
fig1, ax = plt.subplots(1,2)
ax[0].hist(wines.loc[wines['wine_type'] == 'red','alcohol'], bins = 50, color = 'red');
ax[0].set_title('Basic alcohol Plot Red wine')
ax[1].hist(wines.loc[wines['wine_type'] == 'white','alcohol'], bins = 50, color = 'blue');
ax[1].set_title('Basic alcohol  Plot white Wine');

# %%
fig1, ax = plt.subplots(1,2)
ax[0].boxplot(wines.loc[wines['wine_type'] == 'red','quality']);
ax[0].set_title('Basic alcohol Plot Red wine')
ax[1].boxplot(wines.loc[wines['wine_type'] == 'white','quality']);
ax[1].set_title('Basic alcohol  Plot white Wine');

# %%
c_item = {}
for i in wines['quality_label'].unique():
    c_item[i] = wines[wines['quality_label']==i].alcohol
plt.boxplot([x for x in c_item.values()],labels=[x for x in c_item.keys()])
plt.xlabel('quality_label') 
plt.ylabel('alcohol')
plt.title('Analysing quality')
plt.show();

# %%
c_item = {}
for i in wines['quality_label'].unique():
    c_item[i] = wines[red_wine['quality_label']==i].alcohol
plt.boxplot([x for x in c_item.values()],labels=[x for x in c_item.keys()])
plt.xlabel('quality_label') 
plt.ylabel('alcohol')
plt.title('Analysing quality')
plt.show();

# %%
red = wines[wines['wine_type'] == 'red']
c_itemred = {}
for i in red['quality_label'].unique():
    c_itemred[i] = red[red['quality_label']==i].alcohol
plt.boxplot([x for x in c_itemred.values()],labels=[x for x in c_itemred.keys()])
plt.xlabel('quality_label') 
plt.ylabel('alcohol')
plt.title('Red wine')
plt.show();

white = wines[wines['wine_type'] == 'white']
c_itemwhite = {}
for i in white['quality_label'].unique():
    c_itemwhite[i] = white[white['quality_label']==i].alcohol
plt.boxplot([x for x in c_itemwhite.values()],labels=[x for x in c_itemwhite.keys()])
plt.xlabel('quality_label') 
plt.ylabel('alcohol')
plt.title('Red wine')
plt.show();

# %%
fig1, ax = plt.subplots(1,2)
ax[0].boxplot([x for x in c_itemred.values()],labels=[x for x in c_itemred.keys()])
ax[0].set_title('Basic alcohol Plot Red wine')
ax[1].boxplot([x for x in c_itemwhite.values()],labels=[x for x in c_itemwhite.keys()])
ax[1].set_title('Basic alcohol  Plot white Wine');

# %%
def wine_red():
    a = wines[wines['wine_type'] == 'red']
    c_item = {}
    for i in a[b].unique():
         c_item[i] = a[a[b]==i].alcohol
         plt.boxplot([x for x in c_item.values()],labels=[x for x in c_item.keys()])
         plt.xlabel(b) 
         plt.ylabel(alcohol)
         plt.title(a)
         plt.show();
    return c_item

# %%
white = wines[wines['wine_type'] == 'white']
c_itemwhite = {}
for i in white['quality_label'].unique():
    c_itemwhite[i] = white[white['quality_label']==i].alcohol
plt.boxplot([x for x in c_itemwhite.values()],labels=[x for x in c_itemwhite.keys()])
plt.xlabel('quality_label') 
plt.ylabel('alcohol')
plt.title('Red wine')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-328f346d0dc7> in <module>
#       1 red = wines[wines['wine_type'] == 'red']
# ----> 2 wine_red('red',wines['quality_label'])
#
# <ipython-input-41-692387fa776f> in wine_red(a, b)
#       2     # a = wines[wines['wine_type'] == 'red']
#       3     c_item = {}
# ----> 4     for i in a[b].unique():
#       5          c_item[i] = a[a[b]==i].alcohol
#       6          plt.boxplot([x for x in c_item.values()],labels=[x for x in c_item.keys()])
#
# TypeError: string indices must be integers
